# %%
pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.17.1-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.2.1 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torchvision) (2.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: filelock in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (4.9.0)
# Requirement already satisfied: sympy in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (1.12)
# Requirement already satisfied: networkx in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from jinja2->torch==2.2.1->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from sympy->torch==2.2.1->torchvision) (1.3.0)
# Downloading torchvision-0.17.1-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.2 MB 1.7 MB/s eta 0:00:01
#    -------------------- ------------------- 0.6/1.2 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 10.6 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch
# Out:
# Collecting torch
#   Downloading torch-2.2.1-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dandac8719\appdata\local\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Downloading torch-2.2.1-cp311-cp311-win_amd64.whl (198.6 MB)
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/198.6 MB 8.3 MB/s eta 0:00:24
#    ---------------------------------------- 1.2/198.6 MB 19.3 MB/s eta 0:00:11
#    ---------------------------------------- 2.5/198.6 MB 22.6 MB/s eta 0:00:09
#     --------------------------------------- 3.9/198.6 MB 24.8 MB/s eta 0:00:08
#    - -------------------------------------- 5.0/198.6 MB 26.9 MB/s eta 0:00:08
#    - -------------------------------------- 6.4/198.6 MB 25.5 MB/s eta 0:00:08
#    - -------------------------------------- 7.9/198.6 MB 28.0 MB/s eta 0:00:07
#    - -------------------------------------- 9.1/198.6 MB 27.8 MB/s eta 0:00:07
#    -- ------------------------------------- 10.4/198.6 MB 29.7 MB/s eta 0:00:07
#    -- ------------------------------------- 11.6/198.6 MB 31.2 MB/s eta 0:00:06
#    -- ------------------------------------- 13.2/198.6 MB 29.7 MB/s eta 0:00:07
#    -- ------------------------------------- 14.7/198.6 MB 31.2 MB/s eta 0:00:06
#    --- ------------------------------------ 15.8/198.6 MB 31.2 MB/s eta 0:00:06
#    --- ------------------------------------ 17.0/198.6 MB 32.8 MB/s eta 0:00:06
#    --- ------------------------------------ 18.3/198.6 MB 32.8 MB/s eta 0:00:06
#    --- ------------------------------------ 19.6/198.6 MB 31.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 20.9/198.6 MB 32.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 22.2/198.6 MB 31.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 23.4/198.6 MB 32.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 24.7/198.6 MB 32.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 25.9/198.6 MB 32.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 27.2/198.6 MB 31.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 28.3/198.6 MB 32.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 29.2/198.6 MB 29.8 MB/s eta 0:00:06
#    ------ --------------------------------- 30.4/198.6 MB 29.7 MB/s eta 0:00:06
#    ------ --------------------------------- 31.7/198.6 MB 29.7 MB/s eta 0:00:06
#    ------ --------------------------------- 32.9/198.6 MB 29.7 MB/s eta 0:00:06
#    ------ --------------------------------- 33.5/198.6 MB 29.7 MB/s eta 0:00:06
#    ------- -------------------------------- 35.0/198.6 MB 28.4 MB/s eta 0:00:06
#    ------- -------------------------------- 36.3/198.6 MB 28.4 MB/s eta 0:00:06
#    ------- -------------------------------- 37.5/198.6 MB 29.7 MB/s eta 0:00:06
#    ------- -------------------------------- 38.8/198.6 MB 28.5 MB/s eta 0:00:06
#    -------- ------------------------------- 40.0/198.6 MB 29.7 MB/s eta 0:00:06
#    -------- ------------------------------- 41.1/198.6 MB 28.4 MB/s eta 0:00:06
#    -------- ------------------------------- 42.5/198.6 MB 28.4 MB/s eta 0:00:06
#    -------- ------------------------------- 43.8/198.6 MB 28.4 MB/s eta 0:00:06
#    --------- ------------------------------ 45.0/198.6 MB 31.2 MB/s eta 0:00:05
#    --------- ------------------------------ 46.3/198.6 MB 31.2 MB/s eta 0:00:05
#    --------- ------------------------------ 47.6/198.6 MB 29.7 MB/s eta 0:00:06
#    --------- ------------------------------ 48.8/198.6 MB 31.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 49.9/198.6 MB 31.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 51.2/198.6 MB 31.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 52.7/198.6 MB 31.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 54.3/198.6 MB 32.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 55.7/198.6 MB 32.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 57.0/198.6 MB 31.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 58.3/198.6 MB 32.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 59.5/198.6 MB 31.2 MB/s eta 0:00:05
#    ------------ --------------------------- 60.8/198.6 MB 32.7 MB/s eta 0:00:05
#    ------------ --------------------------- 62.1/198.6 MB 32.7 MB/s eta 0:00:05
#    ------------ --------------------------- 63.4/198.6 MB 31.2 MB/s eta 0:00:05
#    ------------- -------------------------- 64.7/198.6 MB 32.7 MB/s eta 0:00:05
#    ------------- -------------------------- 66.0/198.6 MB 32.7 MB/s eta 0:00:05
#    ------------- -------------------------- 67.3/198.6 MB 31.2 MB/s eta 0:00:05
#    ------------- -------------------------- 68.6/198.6 MB 32.7 MB/s eta 0:00:04
#    -------------- ------------------------- 69.9/198.6 MB 32.8 MB/s eta 0:00:04
#    -------------- ------------------------- 71.2/198.6 MB 32.8 MB/s eta 0:00:04
#    -------------- ------------------------- 72.5/198.6 MB 32.7 MB/s eta 0:00:04
#    -------------- ------------------------- 73.7/198.6 MB 32.8 MB/s eta 0:00:04
#    --------------- ------------------------ 75.0/198.6 MB 32.8 MB/s eta 0:00:04
#    --------------- ------------------------ 76.3/198.6 MB 32.8 MB/s eta 0:00:04
#    --------------- ------------------------ 77.6/198.6 MB 32.8 MB/s eta 0:00:04
#    --------------- ------------------------ 79.0/198.6 MB 32.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 80.2/198.6 MB 32.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 81.5/198.6 MB 32.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 82.8/198.6 MB 32.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 84.1/198.6 MB 32.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 85.4/198.6 MB 32.7 MB/s eta 0:00:04
#    ----------------- ---------------------- 86.6/198.6 MB 32.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 87.9/198.6 MB 32.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 89.1/198.6 MB 31.1 MB/s eta 0:00:04
#    ------------------ --------------------- 90.7/198.6 MB 32.8 MB/s eta 0:00:04
#    ------------------ --------------------- 92.1/198.6 MB 32.8 MB/s eta 0:00:04
#    ------------------ --------------------- 93.3/198.6 MB 32.7 MB/s eta 0:00:04
#    ------------------- -------------------- 94.6/198.6 MB 32.8 MB/s eta 0:00:04
#    ------------------- -------------------- 95.8/198.6 MB 31.2 MB/s eta 0:00:04
#    ------------------- -------------------- 97.0/198.6 MB 31.1 MB/s eta 0:00:04
#    ------------------- -------------------- 98.2/198.6 MB 32.7 MB/s eta 0:00:04
#    -------------------- ------------------- 99.5/198.6 MB 31.2 MB/s eta 0:00:04
#    ------------------- ------------------- 100.8/198.6 MB 32.7 MB/s eta 0:00:03
#    -------------------- ------------------ 102.0/198.6 MB 31.2 MB/s eta 0:00:04
#    -------------------- ------------------ 103.2/198.6 MB 32.8 MB/s eta 0:00:03
#    -------------------- ------------------ 104.5/198.6 MB 31.2 MB/s eta 0:00:04
#    -------------------- ------------------ 106.1/198.6 MB 32.7 MB/s eta 0:00:03
#    --------------------- ----------------- 107.3/198.6 MB 31.2 MB/s eta 0:00:03
#    ------------------------------- ------- 158.4/198.6 MB 32.7 MB/s eta 0:00:02
#    ------------------------------- ------- 159.7/198.6 MB 32.8 MB/s eta 0:00:02
#    ------------------------------- ------- 161.0/198.6 MB 31.2 MB/s eta 0:00:02
#    ------------------------------- ------- 162.3/198.6 MB 31.2 MB/s eta 0:00:02
#    -------------------------------- ------ 164.0/198.6 MB 31.2 MB/s eta 0:00:02
#    -------------------------------- ------ 165.2/198.6 MB 32.8 MB/s eta 0:00:02
#    -------------------------------- ------ 166.5/198.6 MB 32.7 MB/s eta 0:00:01
#    -------------------------------- ------ 167.8/198.6 MB 32.8 MB/s eta 0:00:01
#    --------------------------------- ----- 169.1/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------- ----- 170.4/198.6 MB 32.7 MB/s eta 0:00:01
#    --------------------------------- ----- 171.7/198.6 MB 32.8 MB/s eta 0:00:01
#    --------------------------------- ----- 173.0/198.6 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------- ---- 174.2/198.6 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 175.5/198.6 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 176.8/198.6 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 178.0/198.6 MB 31.1 MB/s eta 0:00:01
#    ----------------------------------- --- 179.2/198.6 MB 31.2 MB/s eta 0:00:01
#    ----------------------------------- --- 180.4/198.6 MB 32.8 MB/s eta 0:00:01
#    ----------------------------------- --- 181.6/198.6 MB 31.2 MB/s eta 0:00:01
#    ----------------------------------- --- 182.7/198.6 MB 29.7 MB/s eta 0:00:01
#    ------------------------------------ -- 184.1/198.6 MB 29.7 MB/s eta 0:00:01
#    ------------------------------------ -- 185.4/198.6 MB 31.2 MB/s eta 0:00:01
#    ------------------------------------ -- 186.6/198.6 MB 31.2 MB/s eta 0:00:01
#    ------------------------------------ -- 188.3/198.6 MB 31.2 MB/s eta 0:00:01
#    ------------------------------------- - 189.6/198.6 MB 32.7 MB/s eta 0:00:01
#    ------------------------------------- - 190.8/198.6 MB 31.2 MB/s eta 0:00:01
#    ------------------------------------- - 192.1/198.6 MB 32.8 MB/s eta 0:00:01
#    ------------------------------------- - 193.3/198.6 MB 32.7 MB/s eta 0:00:01
#    --------------------------------------  194.4/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------------  195.7/198.6 MB 29.7 MB/s eta 0:00:01
#    --------------------------------------  197.0/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------------  198.2/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 31.2 MB/s eta 0:00:01
#    --------------------------------------- 198.6/198.6 MB 17.7 MB/s eta 0:00:00
# Installing collected packages: torch
# Successfully installed torch-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import torch
from torchvision import models, transforms
from PIL import Image
import shutil

# Step 1: Load the ResNet50 model
model = models.resnet50(pretrained=True)
model.eval()

# Step 2: Specify the paths to the validation dataset and ground truth labels file
dataset_folder = "C:/Users/DandaC8719/Documents/ILSVRC2012_img_val"
ground_truth_file = "C:/Users/DandaC8719/Documents/ground_truth_ilsvrc2012_val.txt"
output_folder = "C:/Users/DandaC8719/Documents/capstone_overall_code/output_images_folder_50000"

# Step 3: Read the ground truth labels from the file
with open(ground_truth_file, 'r') as file:
    lines = file.readlines()
    ground_truth_labels = [int(label.strip()) for label in lines]

# Step 4: Define the image preprocessing transform
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Step 5: Iterate through the images in the validation dataset
num_correct_predictions = 0
total_images = 0

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(dataset_folder):
    if filename.endswith('.jpg') or filename.endswith('.JPEG'):
        # Construct the full path to the image
        image_path = os.path.join(dataset_folder, filename)

        # Use PIL to open and preprocess the image
        image = Image.open(image_path).convert("RGB")
        input_tensor = preprocess(image).unsqueeze(0)

        # Step 6: Use the model to predict the label
        with torch.no_grad():
            output = model(input_tensor)
            predicted_label = torch.argmax(output, 1).item()

        # Step 7: Compare the predicted label with the ground truth label
        true_label = ground_truth_labels[total_images]
        if predicted_label == true_label:
            num_correct_predictions += 1
            # Step 8: If correctly predicted, copy the image to the output folder
            shutil.copy(image_path, os.path.join(output_folder, filename))
          
        total_images += 1

# Step 9: Calculate the accuracy of the model
accuracy = num_correct_predictions / total_images
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 76.13%
